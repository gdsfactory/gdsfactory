# %%
import gdsfactory as gf

# taken from tests\components\containers\test_add_fiber_array_optical_south_electrical_north.py
c = gf.c.add_fiber_array_optical_south_electrical_north(
    component=gf.c.straight_heater_metal,
    pad=gf.c.pad,
    grating_coupler=gf.c.grating_coupler_te,
    cross_section_metal=gf.cross_section.metal_routing,
    with_loopback=True, pad_pitch=100, pitch=127, pad_gc_spacing=250,
    electrical_port_orientation=90, auto_taper_pads=True
)
c.plot()
