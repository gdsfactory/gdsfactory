# %% [markdown]
# # VScode
#
# This extension is available to install from VScode extensions marketplace.
#
# ![](https://i.imgur.com/89OPCQ1.png)
#
#
# Visual Studio Code is a free open soure popular IDE and editor.
#
# This extension provides you with:
#
# - Useful code snippets
# - Run `pic.yml` netlist directly from the browser
